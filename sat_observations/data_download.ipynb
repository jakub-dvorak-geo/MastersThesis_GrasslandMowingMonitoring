# %%
import sentinelsat
from osgeo import ogr

# %%
dir(ogr)
# Out:
# ['ALTER_ALL_FLAG',
#  'ALTER_DEFAULT_FLAG',
#  'ALTER_NAME_FLAG',
#  'ALTER_NULLABLE_FLAG',
#  'ALTER_TYPE_FLAG',
#  'ALTER_WIDTH_PRECISION_FLAG',
#  'ApproximateArcAngles',
#  'BuildPolygonFromEdges',
#  'CreateGeometryFromEsriJson',
#  'CreateGeometryFromGML',
#  'CreateGeometryFromJson',
#  'CreateGeometryFromWkb',
#  'CreateGeometryFromWkt',
#  'DataSource',
#  'DataSource_swigregister',
#  'DontUseExceptions',
#  'Driver',
#  'Driver_swigregister',
#  'F_VAL_ALL',
#  'F_VAL_ALLOW_NULL_WHEN_DEFAULT',
#  'F_VAL_GEOM_TYPE',
#  'F_VAL_NULL',
#  'F_VAL_WIDTH',
#  'Feature',
#  'FeatureDefn',
#  'FeatureDefn_swigregister',
#  'Feature_swigregister',
#  'FieldDefn',
#  'FieldDefn_swigregister',
#  'ForceTo',
#  'ForceToLineString',
#  'ForceToMultiLineString',
#  'ForceToMultiPoint',
#  'ForceToMultiPolygon',
#  'ForceToPolygon',
#  'GT_Flatten',
#  'GT_GetCollection',
#  'GT_GetCurve',
#  'GT_GetLinear',
#  'GT_HasM',
#  'GT_HasZ',
#  'GT_IsCurve',
#  'GT_IsNonLinear',
# ...

# %%
api = sentinelsat.SentinelAPI(
    'dvorakjakub',
    'uNkYgAsT8Bzr7KM',
    api_url='https://apihub.copernicus.eu/apihub/',
    show_progressbars=True,
    timeout=60)

# %%
query_ro146 = api.query(
    date=('20210501', '20210930'),
    platformname='Sentinel-1',
    raw=None,
    area='POLYGON((15.425 50.74, 15.515 50.74, 15.515 50.635, 15.425 50.635, 15.425 50.74))',
    area_relation='Contains',
    order_by=None,
    limit=200,
    offset=0,
    relativeorbitnumber=146,
    producttype='SLC',
    sensoroperationalmode='IW')

# %%
[[i['endposition'], i['relativeorbitnumber']] for i in query.values()]
# Out:
# [[datetime.datetime(2021, 9, 26, 16, 51, 48, 466000), 146],
#  [datetime.datetime(2021, 9, 20, 16, 52, 29, 343000), 146],
#  [datetime.datetime(2021, 9, 14, 16, 51, 48, 54000), 146],
#  [datetime.datetime(2021, 9, 8, 16, 52, 28, 955000), 146],
#  [datetime.datetime(2021, 9, 2, 16, 51, 47, 529000), 146],
#  [datetime.datetime(2021, 8, 27, 16, 52, 28, 351000), 146],
#  [datetime.datetime(2021, 8, 21, 16, 51, 47, 12000), 146],
#  [datetime.datetime(2021, 8, 15, 16, 52, 27, 706000), 146],
#  [datetime.datetime(2021, 8, 9, 16, 51, 46, 372000), 146],
#  [datetime.datetime(2021, 8, 3, 16, 52, 27, 160000), 146],
#  [datetime.datetime(2021, 7, 28, 16, 51, 45, 797000), 146],
#  [datetime.datetime(2021, 7, 22, 16, 52, 26, 389000), 146],
#  [datetime.datetime(2021, 7, 16, 16, 51, 44, 972000), 146],
#  [datetime.datetime(2021, 7, 10, 16, 52, 25, 663000), 146],
#  [datetime.datetime(2021, 7, 4, 16, 51, 44, 205000), 146],
#  [datetime.datetime(2021, 6, 28, 16, 52, 24, 997000), 146],
# ...

# %%
[i['producttype'] for i in query.values()]
# Out:
# ['SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC',
#  'SLC']

# %%
query
# Out:
# OrderedDict([('768d0957-288d-4038-a5df-ab8d6cfb8d47',
#               {'title': 'S1A_IW_SLC__1SDV_20151221T165044_20151221T165111_009143_00D274_F1E2',
#                'link': "https://apihub.copernicus.eu/apihub/odata/v1/Products('768d0957-288d-4038-a5df-ab8d6cfb8d47')/$value",
#                'link_alternative': "https://apihub.copernicus.eu/apihub/odata/v1/Products('768d0957-288d-4038-a5df-ab8d6cfb8d47')/",
#                'link_icon': "https://apihub.copernicus.eu/apihub/odata/v1/Products('768d0957-288d-4038-a5df-ab8d6cfb8d47')/Products('Quicklook')/$value",
#                'summary': 'Date: 2015-12-21T16:50:44.117Z, Instrument: SAR-C SAR, Mode: VV VH, Satellite: Sentinel-1, Size: 7.29 GB',
#                'ondemand': 'false',
#                'ingestiondate': datetime.datetime(2015, 12, 22, 0, 13, 37, 528000),
#                'beginposition': datetime.datetime(2015, 12, 21, 16, 50, 44, 117000),
# ...
